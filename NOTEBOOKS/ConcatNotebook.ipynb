# %%
import pandas as pd

# %%
df_2015 = pd.read_csv('./export_2015.csv')
df_2016 = pd.read_csv('./export_2016.csv')
df_2017 = pd.read_csv('./export_2017.csv')
df_2018 = pd.read_csv('./export_2018.csv')
df_2019 = pd.read_csv('./export_2019.csv')
df_2020 = pd.read_csv('./export_2020.csv')

# %%
df_concat = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019, df_2020], axis=0)

# %%
df_concat
# Out:
#       Unnamed: 0   age          BuildingType           Neighborhood  \
# 0              0  48.0  Multifamily LR (1-4)  MAGNOLIA / QUEEN ANNE
# 1              1  23.0        NonResidential       GREATER DUWAMISH
# 2              2   8.0  Multifamily HR (10+)               DOWNTOWN
# 3              3  25.0        NonResidential             LAKE UNION
# 4              4   7.0        NonResidential       GREATER DUWAMISH
# ...          ...   ...                   ...                    ...
# 3623        3623   1.0        NonResidential              NORTHWEST
# 3624        3624   2.0  Multifamily MR (5-9)  MAGNOLIA / QUEEN ANNE
# 3625        3625  60.0        NonResidential  MAGNOLIA / QUEEN ANNE
# 3626        3626  18.0  Multifamily MR (5-9)                CENTRAL
# 3627        3627   2.0  Multifamily MR (5-9)                BALLARD
#
#       NumberofBuildings  PropertyGFATotal  SiteEnergyUse(kBtu)  \
# 0                   1.0             40086                  NaN
# ...

# %%
df_final = df_concat.drop(['Unnamed: 0', 'NumberofBuildings'], axis=1)

# %%
df_final
# Out:
#        age          BuildingType           Neighborhood  PropertyGFATotal  \
# 0     48.0  Multifamily LR (1-4)  MAGNOLIA / QUEEN ANNE             40086
# 1     23.0        NonResidential       GREATER DUWAMISH             22452
# 2      8.0  Multifamily HR (10+)               DOWNTOWN             90959
# 3     25.0        NonResidential             LAKE UNION            282863
# 4      7.0        NonResidential       GREATER DUWAMISH             63225
# ...    ...                   ...                    ...               ...
# 3623   1.0        NonResidential              NORTHWEST            213065
# 3624   2.0  Multifamily MR (5-9)  MAGNOLIA / QUEEN ANNE            182411
# 3625  60.0        NonResidential  MAGNOLIA / QUEEN ANNE             20289
# 3626  18.0  Multifamily MR (5-9)                CENTRAL            183379
# 3627   2.0  Multifamily MR (5-9)                BALLARD            189044
#
#       SiteEnergyUse(kBtu)  SteamUse(kBtu)  Electricity(kBtu)  \
# ...

# %%
df_final.to_csv('concat_datasets.csv')
